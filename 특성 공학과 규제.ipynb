# %%
import pandas as pd
df = pd.read_csv('https://bit.ly/perch_csv_data')
# print(df)
perch_full = df.to_numpy()
print(perch_full)
# Out:
# [[ 8.4   2.11  1.41]
#  [13.7   3.53  2.  ]
#  [15.    3.82  2.43]
#  [16.2   4.59  2.63]
#  [17.4   4.59  2.94]
#  [18.    5.22  3.32]
#  [18.7   5.2   3.12]
#  [19.    5.64  3.05]
#  [19.6   5.14  3.04]
#  [20.    5.08  2.77]
#  [21.    5.69  3.56]
#  [21.    5.92  3.31]
#  [21.    5.69  3.67]
#  [21.3   6.38  3.53]
#  [22.    6.11  3.41]
#  [22.    5.64  3.52]
#  [22.    6.11  3.52]
#  [22.    5.88  3.52]
#  [22.    5.52  4.  ]
#  [22.5   5.86  3.62]
#  [22.5   6.79  3.62]
#  [22.7   5.95  3.63]
#  [23.    5.22  3.63]
#  [23.5   6.28  3.72]
#  [24.    7.29  3.72]
#  [24.    6.38  3.82]
#  [24.6   6.73  4.17]
#  [25.    6.44  3.68]
#  [25.6   6.56  4.24]
#  [26.5   7.17  4.14]
#  [27.3   8.32  5.14]
#  [27.5   7.17  4.34]
#  [27.5   7.05  4.34]
#  [27.5   7.28  4.57]
#  [28.    7.82  4.2 ]
#  [28.7   7.59  4.64]
#  [30.    7.62  4.77]
#  [32.8  10.03  6.02]
#  [34.5  10.26  6.39]
#  [35.   11.49  7.8 ]
#  [36.5  10.88  6.86]
#  [36.   10.61  6.74]
#  [37.   10.84  6.26]
# ...

# %%
import numpy as np
perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])

# %%
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(
    perch_full, perch_weight, random_state=42
)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures()
poly.fit([[2,3]])
print(poly.transform([[2,3]]))
# Out:
# [[1. 2. 3. 4. 6. 9.]]

# %%
poly = PolynomialFeatures(include_bias=False) # 절편에 곱하는 1 삭제
poly.fit([[2,3]])
print(poly.transform([[2,3]])) # 특성의 제곱과 특성끼리 곱한 항만 추가
# Out:
# [[2. 3. 4. 6. 9.]]

# %%
poly = PolynomialFeatures(include_bias=False) # 변환기 생성
poly.fit(train_input)
train_poly = poly.transform(train_input)
print(train_poly.shape)
# Out:
# (42, 9)

# %%
# 어떤 조합으로 특성이 만들어졌는지 나옴
poly.get_feature_names_out()
# Out:
# array(['x0', 'x1', 'x2', 'x0^2', 'x0 x1', 'x0 x2', 'x1^2', 'x1 x2',
#        'x2^2'], dtype=object)

# %%
test_poly = poly.transform(test_input) # 조합 방법을 테스트 인풋에도 적용

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train_poly, train_target)
print(lr.score(train_poly, train_target))
# Out:
# 0.9903183436982125

# %%
print(lr.score(test_poly, test_target))
# Out:
# 0.9714559911594111

# %%
poly = PolynomialFeatures(degree=5, include_bias=False)
poly.fit(train_input)
train_poly = poly.transform(train_input)
test_poly = poly.transform(test_input)
print(train_poly.shape)
# Out:
# (42, 55)

# %%
lr.fit(train_poly, train_target)
print(lr.score(train_poly, train_target))
# Out:
# 0.9999999999996433

# %%
print(lr.score(test_poly, test_target))
# Out:
# -144.40579436844948

# %%
# git에 push
# 구글 드라이브 마운트 후
# %cd /content/drive/MyDrive/Colab Notebooks/혼자 공부하는 머신러닝 딥러닝
# %pwd
# !git config --global user.email "haeun8701@gmail.com"
# !git config --global user.name "hann0079"
# !git remote add origin https://github.com/hann0079/Machine-Learning.git
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/혼자 공부하는 머신러닝 딥러닝/.git/
